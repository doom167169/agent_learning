# %% [markdown]
# ## 1. 初始化客户端
# ### 1.1. 硬编码API_KEY

# %%
from openai import OpenAI

# 创建 OpenAI 客户端
client = OpenAI(
    api_key="sk-bfb80d99f1f643a3a5c370115886da92",
    base_url="https://api.deepseek.com",
)

# %% [markdown]
# ### 1.2 从环境变量中获取API_KEY

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("DEEPSEEK_API_KEY")
print(api_key)

client = OpenAI(
    api_key=api_key,
    base_url="https://api.deepseek.com",
)
# Out:
# sk-bfb80d99f1f643a3a5c370115886da92

# %% [markdown]
# ## 2.访问模型

# %%
print("正在调用大模型....")
response = client.chat.completions.create(
    model="deepseek-v4-flash",
    messages=[
        {"role": "system", "content": "你是一名友好的AI助教。"},
        {"role": "user", "content": "你好，你是谁？"}
    ],
    stream=False,
    temperature=0.9
)
print("成功调用大模型")
# Out:
# 正在调用大模型....
# 成功调用大模型

# %% [markdown]
# ## 3.获取模型响应结果

# %%
print(response.model_dump_json())
# Out:
# {"id":"bdecc2bd-0c21-4b1f-88fe-bfedaca87273","choices":[{"finish_reason":"stop","index":0,"logprobs":null,"message":{"content":"你好！我是你的友好AI助教，很高兴认识你！我可以帮你解答问题、提供学习建议、解决问题，或者随时陪你聊聊天。有什么可以帮你的吗？😊","refusal":null,"role":"assistant","annotations":null,"audio":null,"function_call":null,"tool_calls":null,"reasoning_content":"嗯，用户问了一个简单的自我介绍问题。作为AI助手，需要清晰说明自己的身份和功能。可以用友好的语气直接回应，明确表示自己是虚拟AI助手，并解释主要用途。不需要过多修饰，保持简洁明了。"}}],"created":1785135229,"model":"deepseek-v4-flash","object":"chat.completion","moderation":null,"service_tier":null,"system_fingerprint":"fp_8b330d02d0_prod0820_fp8_kvcache_20260402","usage":{"completion_tokens":86,"prompt_tokens":15,"total_tokens":101,"completion_tokens_details":{"accepted_prediction_tokens":null,"audio_tokens":null,"reasoning_tokens":47,"rejected_prediction_tokens":null},"prompt_tokens_details":{"audio_tokens":null,"cache_write_tokens":null,"cached_tokens":0},"prompt_cache_hit_tokens":0,"prompt_cache_miss_tokens":15}}

# %%
print(response.choices[0].message.content)
# Out:
# 你好！我是你的友好AI助教，很高兴认识你！我可以帮你解答问题、提供学习建议、解决问题，或者随时陪你聊聊天。有什么可以帮你的吗？😊

# %%
response = client.chat.completions.create(
    model="deepseek-v4-flash",
    messages=[
        {"role": "user", "content": "明天佛山天气怎么样"}
    ],
    stream=False,
    temperature=0.9
)
print(response.choices[0].message.content)
# Out:
# 抱歉，我无法直接提供实时天气信息。建议你**打开联网搜索功能**查询，或者直接查看手机上的天气App、访问中国天气网等官方渠道，这样可以获取最准确的佛山明天天气预报。
